# %%
import pandas as pd


df = pd.read_csv('datatest__.csv')
df
# Out:
#                                           description  \
# 0               Gestion d'installations informatiques
# 1      Conseil en systèmes et logiciels informatiques
# 2                       Ingénierie, études techniques
# 3      Conseil en systèmes et logiciels informatiques
# 4                       Ingénierie, études techniques
# 5   Conseil pour les affaires et autres conseils d...
# 6                  Activités des agences de publicité
# 7                              Enseignement supérieur
# 8                        Activités des sièges sociaux
# 9              Vente à distance sur catalogue général
# 10     Conseil en systèmes et logiciels informatiques
# 11          Édition de logiciels système et de réseau
# 12             Vente à distance sur catalogue général
# 13                      Ingénierie, études techniques
# 14             Vente à distance sur catalogue général
# 15                       Formation continue d'adultes
# ...

# %%
df['telephone'] = df['telephone'].replace('Modifier ces informations', '')

df['telephone']

df
# Out:
#                                           description  \
# 0               Gestion d'installations informatiques
# 1      Conseil en systèmes et logiciels informatiques
# 2                       Ingénierie, études techniques
# 3      Conseil en systèmes et logiciels informatiques
# 4                       Ingénierie, études techniques
# 5   Conseil pour les affaires et autres conseils d...
# 6                  Activités des agences de publicité
# 7                              Enseignement supérieur
# 8                        Activités des sièges sociaux
# 9              Vente à distance sur catalogue général
# 10     Conseil en systèmes et logiciels informatiques
# 11          Édition de logiciels système et de réseau
# 12             Vente à distance sur catalogue général
# 13                      Ingénierie, études techniques
# 14             Vente à distance sur catalogue général
# 15                       Formation continue d'adultes
# ...
